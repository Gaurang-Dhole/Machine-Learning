# %%
import numpy as np
import pandas as pd

# %%
db = pd.read_csv('enjoysport.csv')

# %%
db.head()
# Out:
#      sky airtemp humidity    wind water forcast enjoysport
# 0  sunny    warm   normal  strong  warm    same        yes
# 1  sunny    warm     high  strong  warm    same        yes
# 2  rainy    cold     high  strong  warm  change         no
# 3  sunny    warm     high  strong  cool  change        yes

# %%
temp_db = pd.get_dummies(db['enjoysport'])
temp_db
# Out:
#       no    yes
# 0  False   True
# 1  False   True
# 2   True  False
# 3  False   True

# %%
con_db = pd.concat((db, temp_db), axis = 1)
con_db
# Out:
#      sky airtemp humidity    wind water forcast enjoysport     no    yes
# 0  sunny    warm   normal  strong  warm    same        yes  False   True
# 1  sunny    warm     high  strong  warm    same        yes  False   True
# 2  rainy    cold     high  strong  warm  change         no   True  False
# 3  sunny    warm     high  strong  cool  change        yes  False   True

# %%
con_db = con_db.drop(["enjoysport"], axis = 1)

# %%
con_db
# Out:
#      sky airtemp humidity    wind water forcast     no    yes
# 0  sunny    warm   normal  strong  warm    same  False   True
# 1  sunny    warm     high  strong  warm    same  False   True
# 2  rainy    cold     high  strong  warm  change   True  False
# 3  sunny    warm     high  strong  cool  change  False   True

# %%
con_db = con_db.drop(["no"], axis = 1)

# %%
con_db
# Out:
#      sky airtemp humidity    wind water forcast    yes
# 0  sunny    warm   normal  strong  warm    same   True
# 1  sunny    warm     high  strong  warm    same   True
# 2  rainy    cold     high  strong  warm  change  False
# 3  sunny    warm     high  strong  cool  change   True

# %%
con_db = con_db.rename(columns={"yes" : "enjoysport"})

# %%
con_db
# Out:
#      sky airtemp humidity    wind water forcast  enjoysport
# 0  sunny    warm   normal  strong  warm    same        True
# 1  sunny    warm     high  strong  warm    same        True
# 2  rainy    cold     high  strong  warm  change       False
# 3  sunny    warm     high  strong  cool  change        True

# %%
db = con_db
db
# Out:
#      sky airtemp humidity    wind water forcast  enjoysport
# 0  sunny    warm   normal  strong  warm    same        True
# 1  sunny    warm     high  strong  warm    same        True
# 2  rainy    cold     high  strong  warm  change       False
# 3  sunny    warm     high  strong  cool  change        True

# %%
n = len(db)
n
# Out:
# 4

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Miniconda3\envs\env01\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 3
#       1 hypo = []
#       2 for i  in range(n):
# ...
